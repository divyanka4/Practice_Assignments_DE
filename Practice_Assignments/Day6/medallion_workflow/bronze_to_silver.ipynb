# %%
dbutils.widgets.text("catalog","default")
catalog = dbutils.widgets.get("catalog")

# %%
df_sales = spark.read.table(f"{catalog}.bronze.sale_tbl")

# %%
df_sales.printSchema() #Check Data Types

# %%
df_sales_cleaned = df_sales.dropna().dropDuplicates().drop("ingestion_time")

# %%
df_sales_cleaned.write.mode("overwrite").saveAsTable(f"{catalog}.silver.sale_cln_tbl")
