# %%
dbutils.widgets.text("catalog", "default")
catalog = dbutils.widgets.get("catalog")

# %%
# %sql 
CREATE OR REPLACE TABLE IDENTIFIER(:catalog || '.gold.daily_sales_summary') 
USING DELTA AS

SELECT 
    order_date,
    ROUND(SUM(total_amount),2) AS total_revenue, 
    COUNT(DISTINCT order_id) AS total_orders,
    COUNT(DISTINCT customer_id) AS total_customers,
    COUNT(DISTINCT product_id) AS total_products,
    SUM(quantity) AS total_units,
    ROUND(SUM(discount_amount), 2) AS total_discounts
FROM IDENTIFIER (:catalog || '.silver.sale_cln_tbl')
    GROUP BY order_date

# %%
# %sql
SELECT * FROM IDENTIFIER(:catalog || '.gold.daily_sales_summary')
