# %%
# %run "/Workspace/Users/paldivya0222@gmail.com/Practice_Assignments_DE/Practice_Assignments/Day6/medallion_workflow/includes"

# %%
dbutils.widgets.text("catalog", "default")
catalog = dbutils.widgets.get("catalog")

# %%
df = spark.read.csv(f"{input_path}sales_csv.csv", header=True, inferSchema=True)

# %%
df1 = add_metadata_col(df)

# %%
df1.write.mode("overwrite").saveAsTable(f"{catalog}.bronze.sale_tbl")
